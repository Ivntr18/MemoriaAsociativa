# %%
import numpy as np

# %%
tables=np.load("tables.npy")
dicY={'a':0,'b':1,'d':2,'e':3,'f':4,'g':5,'i':6,'k':7,'l':8,'m':9,'n':10,'n~':11,'o':12,'p':13,'r':14,'r(':15,'s':16,'t':17,'tS':18,'u':19,'x':20,'Z':21}

# %%
for j in dicY:
    print j

# %%
i=0
tables[i]
# Out:
# array([[2.6690e+03, 1.6250e+03, 1.1330e+03, 1.9313e+04, 1.0440e+03],
#        [4.7900e+02, 1.6700e+02, 8.9000e+02, 2.1746e+04, 3.1200e+02],
#        [1.2580e+03, 6.0600e+02, 1.3850e+03, 2.0472e+04, 6.5200e+02],
#        [3.0730e+03, 1.0110e+03, 5.6100e+02, 1.9481e+04, 2.0620e+03],
#        [1.4500e+02, 7.7000e+01, 1.7000e+01, 2.2953e+04, 6.8000e+01],
#        [2.1700e+02, 4.3000e+01, 2.9700e+02, 2.2601e+04, 1.7400e+02],
#        [1.8610e+03, 1.2400e+03, 9.3600e+02, 2.0318e+04, 6.2100e+02],
#        [8.4700e+02, 5.8100e+02, 1.9600e+02, 2.2072e+04, 2.6600e+02],
#        [1.3060e+03, 7.1700e+02, 1.4090e+03, 2.0400e+04, 5.8900e+02],
#        [6.2900e+02, 1.6700e+02, 1.3300e+02, 2.2353e+04, 4.6200e+02],
#        [1.7300e+03, 8.6700e+02, 7.0600e+02, 2.0679e+04, 8.6300e+02],
#        [2.7000e+01, 8.0000e+00, 1.2400e+02, 2.2964e+04, 1.9000e+01],
#        [2.3580e+03, 8.8300e+02, 9.1900e+02, 1.9838e+04, 1.4750e+03],
#        [5.3200e+02, 2.1700e+02, 1.5100e+02, 2.2432e+04, 3.1500e+02],
# ...

# %%
tables[i,:,0]/tables[i,:,0].sum()
# Out:
# array([0.11546615, 0.02072247, 0.05442353, 0.13294398, 0.00627298,
#        0.00938784, 0.08051049, 0.03664287, 0.05650011, 0.02721177,
#        0.07484318, 0.00116807, 0.10201168, 0.02301536, 0.00821977,
#        0.06610426, 0.10218473, 0.04179104, 0.00194679, 0.02894225,
#        0.00679213, 0.00289855])

# %%
tables[i,:,1]/(tables[i,:,1]+tables[i,:,2])
# Out:
# array([0.58919507, 0.15799432, 0.30436966, 0.64312977, 0.81914894,
#        0.12647059, 0.56985294, 0.74774775, 0.33725306, 0.55666667,
#        0.5511761 , 0.06060606, 0.4900111 , 0.58967391, 0.53535354,
#        0.37677054, 0.96538644, 0.60865385, 0.9       , 0.28018576,
#        0.74603175, 0.25806452])

# %%
tables[i,:,1]/(tables[i,:,1]+tables[i,:,4])
# Out:
# array([0.60884226, 0.34864301, 0.48171701, 0.32899447, 0.53103448,
#        0.19815668, 0.66630844, 0.68595041, 0.54900459, 0.26550079,
#        0.50115607, 0.2962963 , 0.37446989, 0.40789474, 0.27894737,
#        0.43520942, 0.86198137, 0.6552795 , 0.6       , 0.27055306,
#        0.59872611, 0.35820896])
